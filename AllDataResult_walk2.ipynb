# %%
import pandas as pd

from matplotlib import pyplot as plt

# %%
df = pd.read_csv('AllResult_Walk2.csv')

# %%
x = df['acf_x']
y = df['acf_y']
z = df['acf_z']
id = df['id']

# %%
max(x), max(y), max(z)
# Out:
# (0.8764118489724305, 0.9533499225182658, 0.9401709335983272)

# %%
min(x), min(y), min(z)
# Out:
# (0.24457718008049245, 0.4891830123476794, 0.3458608659431781)

# %%
plt.figure(figsize=(30, 5))
plt.plot(x)
plt.show()

# %%
plt.figure(figsize=(30, 5))
plt.plot(z)
plt.show()

# %%
df.loc[(df['acf_x']<0.6)&(df['acf_z']<0.6), :]
# Out:
#          id     acf_x     acf_y     acf_z
# 48    70638  0.550319  0.737656  0.584007
# 49    70742  0.558596  0.836402  0.588646
# 94   224954  0.562689  0.787637  0.479686
# 115  255651  0.394435  0.729698  0.597487
# 116  255755  0.501710  0.909921  0.558586
# 172  309030  0.290999  0.829639  0.518654
# 209  320631  0.517658  0.791596  0.445761
# 214  321634  0.271722  0.489183  0.345861
# 217  322637  0.495346  0.753401  0.589554
# 316  373754  0.484864  0.766648  0.532212
# 335  410942  0.537297  0.741548  0.590383
# 356  451225  0.514472  0.759151  0.576654

# %%
df.loc[(df['acf_x']<0.6)&(df['acf_z']<0.6)&(df['acf_y']<0.6), :]
# Out:
#          id     acf_x     acf_y     acf_z
# 214  321634  0.271722  0.489183  0.345861

# %%
df.loc[(df['acf_x']<0.6), :]
# Out:
#          id     acf_x     acf_y     acf_z
# 8     14950  0.595993  0.890688  0.768796
# 9     15953  0.565442  0.802591  0.668266
# 10    16124  0.581136  0.819676  0.631314
# 11    17127  0.594852  0.771766  0.707401
# 16    20212  0.481401  0.903449  0.849869
# ..      ...       ...       ...       ...
# 386  462542  0.549259  0.658836  0.771881
# 388  462958  0.556126  0.625385  0.753462
# 390  463753  0.380886  0.734945  0.931560
# 392  465135  0.465417  0.592828  0.649227
# 394  469355  0.426481  0.798330  0.869793
#
# [128 rows x 4 columns]

# %%
df.loc[(df['acf_z']<0.6), :]
# Out:
#          id     acf_x     acf_y     acf_z
# 48    70638  0.550319  0.737656  0.584007
# 49    70742  0.558596  0.836402  0.588646
# 56   135022  0.748486  0.845153  0.431971
# 94   224954  0.562689  0.787637  0.479686
# 115  255651  0.394435  0.729698  0.597487
# 116  255755  0.501710  0.909921  0.558586
# 172  309030  0.290999  0.829639  0.518654
# 205  320215  0.771021  0.796616  0.513378
# 209  320631  0.517658  0.791596  0.445761
# 214  321634  0.271722  0.489183  0.345861
# 217  322637  0.495346  0.753401  0.589554
# 249  355444  0.821088  0.884007  0.511661
# 263  357450  0.647807  0.788773  0.589746
# 270  360431  0.635630  0.707565  0.509226
# 273  362125  0.686720  0.744082  0.599275
# 278  363232  0.715357  0.830329  0.555925
# 285  365030  0.687273  0.763150  0.524698
# 313  372127  0.706440  0.824592  0.554707
# 316  373754  0.484864  0.766648  0.532212
# 319  400940  0.729674  0.711719  0.568246
# 333  410526  0.670510  0.578520  0.583342
# 335  410942  0.537297  0.741548  0.590383
# 345  413847  0.686534  0.750494  0.579441
# 347  414330  0.676165  0.729684  0.446022
# 351  418342  0.718627  0.711548  0.548413
# 356  451225  0.514472  0.759151  0.576654

# %%
df.loc[(df['acf_y']<0.6), :]
# Out:
#          id     acf_x     acf_y     acf_z
# 2      2838  0.658874  0.590350  0.798568
# 78   216854  0.775037  0.591250  0.701458
# 165  307752  0.439585  0.590249  0.655351
# 214  321634  0.271722  0.489183  0.345861
# 247  355028  0.689013  0.518696  0.822274
# 333  410526  0.670510  0.578520  0.583342
# 380  460224  0.786781  0.585101  0.753649
# 383  461227  0.695604  0.563318  0.822241
# 392  465135  0.465417  0.592828  0.649227
